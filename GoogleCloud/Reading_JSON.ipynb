# %% [markdown]
# <a href="https://colab.research.google.com/github/shovitraj/GCloud/blob/main/Reading_JSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade google-cloud-vision
# !pip install --upgrade google-cloud-storage

# %%
from google.colab import files
uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f0caaef2-5935-40b2-b06a-0d9977fe07a0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0caaef2-5935-40b2-b06a-0d9977fe07a0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving apiResponse.json to apiResponse.json
# User uploaded file "apiResponse.json" with length 2105081 bytes

# %%
import os, io
# Imports Credential File:
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "avid-atrium-296502-9e6921103dfe.json"
print("Service Account Key: {}".format(os.environ["GOOGLE_APPLICATION_CREDENTIALS"]))
# Out:
# Service Account Key: avid-atrium-296502-9e6921103dfe.json

# %%
# # Import the Google Cloud client library and JSON library
# from google.cloud import storage
# import json

# # Instantiate a Google Cloud Storage client and specify required bucket and file
# storage_client = storage.Client()
# bucket = storage_client.get_bucket('meropdf')
# blob = bucket.blob('https://storage.cloud.google.com/meropdf/pdf_resultoutput-1-to-2.json')

# # Download the contents of the blob as a string and then parse it using json.loads() method
# data = json.loads(blob.download_as_string(client=None))

# %%
import json

# %%
# #read file
# with open('pdf_resultoutput-1-to-2.json') as myfile:
#   data = myfile.read()

# %%
# #parse file
# obj = json.loads(data)

# %%
# print(data)
# Out:
# {"inputConfig":{"gcsSource":{"uri":"gs://meropdf/Syllabus.pdf"},"mimeType":"application/pdf"},"responses":[{"fullTextAnnotation":{"pages":[{"width":612,"height":792,"blocks":[{"boundingBox":{"normalizedVertices":[{"x":0.11764706,"y":0.04419192},{"x":0.5506536,"y":0.04419192},{"x":0.5506536,"y":0.058080807},{"x":0.11764706,"y":0.058080807}]},"paragraphs":[{"boundingBox":{"normalizedVertices":[{"x":0.11764706,"y":0.04419192},{"x":0.5506536,"y":0.04419192},{"x":0.5506536,"y":0.058080807},{"x":0.11764706,"y":0.058080807}]},"words":[{"boundingBox":{"normalizedVertices":[{"x":0.11764706,"y":0.04419192},{"x":0.16830066,"y":0.04419192},{"x":0.16830066,"y":0.058080807},{"x":0.11764706,"y":0.058080807}]},"symbols":[{"boundingBox":{"normalizedVertices":[{"x":0.11764706,"y":0.04419192},{"x":0.12745099,"y":0.04419192},{"x":0.12745099,"y":0.058080807},{"x":0.11764706,"y":0.058080807}]},"text":"P","confidence":1},{"boundingBox":{"normalizedVertices":[{"x":0.12908497,"y":0.04419192},{"x":0.14215687,
# ...

# %%
def readJson(json_filename):
  with open(json_filename) as myfile:
    data = myfile.read()
  return print(data)

# %%
readJson('apiResponse.json')
